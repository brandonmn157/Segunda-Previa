# %%
class Octal: #creamos una clase octal, cuyos numeros van del 0 al 7
  #La base es 8
  base = 8 
  #Se define una lista vacia
  lista_octal = [] 

  #Creamos la cadena_octal
  def __init__ (self,cadena_octal):
  #Definimos a self.cadena_octal como cadena_octal
    self.cadena_octal = cadena_octal
  #Convertimos la cadena que almacena el Octal, en una lista de strings ('')
    self.lista_octal = list(self.cadena_octal)
    #Convertimos la lista de strings en una lista de enteros
    #Creamos la variable i con valor a 0
    i = 0
    #Creamos una funcion for donde se definen los valores de self.lista_octal
    for dato in self.lista_octal:
      self.lista_octal[i] = int(dato)
      #Sumamos 1 a la variable i para poder desplazarnos en la lista
      i = i + 1
    #Invertimos la lista para que coincida con los octales en metamáticas
    self.lista_octal = list(reversed(self.lista_octal))

  #Creamos la funcion decimal
  def decimal(self):
  #Creamos la variable numero_decimal = 0
    numero_decimal = 0
  #Creamos la variable i con valor a 0
    i = 0
  #Creamos una funcion for donde se definen los valores de self.lista_octal
    for dato in self.lista_octal:
  #creamos la variable numero_decimal y le sumamos la base elevada i * lista_octal en posicion i
      numero_decimal += self.base**i * self.lista_octal[i]
  #Sumamos 1 a la variable i para poder desplazarnos en la lista
      i = i + 1
  #Retornamos la variable numero_decimal
    return numero_decimal

  #Creamos la clase string
  def string(self):
  #Se imprime la cadena_octal
    print(self.cadena_octal)
  #Se imprime la lista_octal
    print(self.lista_octal)

#Se donomina la variable a como clase octal con el valor "1037"
a = Octal("1037")
a.string()
print(a.decimal())
# Out:
# 1037
# [7, 3, 0, 1]
# 543

# %%
class Binario:
  pass

a = Binario()

# %%
class Binario:
  def __init__(self):
    print("Este es el constructor")

a = Binario()
# Out:
# Este es el constructor

# %%
class Binario:
  def __init__(self,dato):
    self.dato = dato

a = Binario("1001")
print(a.dato)
# Out:
# 1001

# %%
class Binario:
  def __init__(self,dato):
    self.dato = dato
  def string(self):
    print(self.dato)

a = Binario("1001")
a.string()
# Out:
# 1001

# %%
class Binario:
  lista_binaria = [] 

  def __init__ (self,cadena_binaria):
    self.cadena_binaria = cadena_binaria
    self.lista_binaria = list(self.cadena_binaria) 
  def string(self):
    print(self.cadena_binaria)
    print(self.lista_binaria)

a = Binario("1001")
a.string()
# Out:
# 1001
# ['1', '0', '0', '1']

# %%
class Binario:
  lista_binario = []

  def __init__(self,cadena_binaria):
    self.cadena_binaria = cadena_binaria
    self.lista_binaria = list( self.cadena_binaria)

    i = 0
    for dato in self.lista_binaria:
      self.lista_binaria[i] = int(dato)
      i = i + 1

  def string(self):
    print(self.cadena_binaria)
    print(self.lista_binaria)

a = Binario("1001")
a.string()
# Out:
# 1001
# [1, 0, 0, 1]

# %%
class Binario:
  lista_octal = []

  def __init__(self,cadena_binaria):
    self.cadena_binaria = cadena_binaria
    self.lista_binaria = list(self.cadena_binaria)

    i = 0
    for dato in self.lista_binaria:
      self.lista_binaria[i] = int(dato)
      i = i + 1

    self.lista_binaria = list(reversed(self.lista_binaria))

  def string(self):
    print(self.cadena_binaria)
    print(self.lista_binaria)

a = Binario("1001")
a.string()
# Out:
# 1001
# [1, 0, 0, 1]

# %%
class Binario:
  base = 2
  lista_binaria = []

  def __init__(self,cadena_binaria):
    self.cadena_binaria = cadena_binaria
    self.lista_binaria = list(self.cadena_binaria)

    i = 0
    for dato in self.lista_binaria:
      self.lista_binaria[i] = int(dato)
      i = i + 1

    self.lista_binaria = list(reversed(self.lista_binaria))

  def decimal(self):
    numero_decimal = 0
    i = 0
    for dato in self.lista_binaria:
      numero_decimal += self.base**1 * self.lista_binaria[i]
      i = i + 1
    return numero_decimal

  def string(self):
    print(self.cadena_binaria)
    print(self.lista_binaria)

a = Binario("1001")
a.string()
print(a.decimal())
# Out:
# 1001
# [1, 0, 0, 1]
# 4
